# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = './network_trace/'
networks = []
for i in range(20):
    network = pd.read_csv(file_path+str(i),delimiter = ' ',names=['time','throughput'])
    networks.append(network)

# %%
fig = plt.figure(dpi=100,figsize=(16,80),constrained_layout=True)
for i in range(len(networks)):
    network = networks[i]
    ax = fig.add_subplot(20,1,i+1)
    ax.set_ylim(0,6)
    ax.plot(network['time'],network['throughput'])
    print(network['throughput'].describe())
plt.show()
# Out:
# count    5880.000000
# mean        1.639240
# std         0.794953
# min         0.200000
# 25%         1.025987
# 50%         1.496345
# 75%         2.119134
# max         6.073426
# Name: throughput, dtype: float64
# count    5880.000000
# mean        1.646814
# std         0.789799
# min         0.200000
# 25%         1.046272
# 50%         1.501850
# 75%         2.121866
# max         5.554752
# Name: throughput, dtype: float64
# count    5880.000000
# mean        1.572694
# std         0.756822
# min         0.200000
# 25%         0.998756
# 50%         1.431559
# 75%         2.007482
# max         5.116822
# Name: throughput, dtype: float64
# count    5880.000000
# mean        1.632853
# std         0.817316
# min         0.200000
# 25%         0.993530
# 50%         1.478645
# 75%         2.118982
# max         5.697373
# Name: throughput, dtype: float64
# count    5880.000000
# mean        1.590489
# std         0.774355
# min         0.200000
# 25%         0.989108
# 50%         1.463746
# 75%         2.035003
# max         5.316171
# Name: throughput, dtype: float64
# count    5880.000000
# mean        1.582860
# std         0.789643
# min         0.200000
# 25%         0.972230
# 50%         1.425337
# 75%         2.051263
# max         5.066436
# Name: throughput, dtype: float64
# count    5880.000000
# mean        1.620369
# std         0.807035
# min         0.200000
# 25%         0.998077
# 50%         1.460636
# 75%         2.105820
# max         5.999323
# Name: throughput, dtype: float64
# count    5880.000000
# mean        1.630145
# std         0.789690
# min         0.200000
# 25%         1.021634
# 50%         1.486162
# 75%         2.114664
# max         5.164020
# Name: throughput, dtype: float64
# count    5880.000000
# mean        1.691533
# std         0.824288
# min         0.200000
# 25%         1.050596
# 50%         1.558886
# 75%         2.193574
# max         5.218475
# Name: throughput, dtype: float64
# count    5880.000000
# mean        1.598350
# std         0.776198
# min         0.200000
# 25%         0.995985
# 50%         1.459685
# 75%         2.063592
# max         5.528585
# Name: throughput, dtype: float64
# count    5880.000000
# mean        1.648675
# std         0.917733
# min         0.200000
# 25%         0.938141
# 50%         1.471185
# 75%         2.198255
# max         5.833054
# Name: throughput, dtype: float64
# count    5880.000000
# mean        1.489905
# std         0.807640
# min         0.200000
# 25%         0.897996
# 50%         1.316017
# 75%         1.931746
# max         5.829624
# Name: throughput, dtype: float64
# count    5880.000000
# mean        1.613366
# std         0.883166
# min         0.200000
# 25%         0.937451
# 50%         1.452590
# 75%         2.108980
# max         6.344063
# Name: throughput, dtype: float64
# count    5880.000000
# mean        1.548199
# std         0.853144
# min         0.200000
# 25%         0.922986
# 50%         1.354811
# 75%         2.016384
# max         5.749135
# Name: throughput, dtype: float64
# count    5880.000000
# mean        1.652967
# std         0.877815
# min         0.200000
# 25%         1.004833
# 50%         1.490519
# 75%         2.157335
# max         6.190227
# Name: throughput, dtype: float64
# count    5880.000000
# mean        1.557120
# std         0.867518
# min         0.200000
# 25%         0.898858
# 50%         1.353709
# 75%         2.042061
# max         5.811503
# Name: throughput, dtype: float64
# count    5880.000000
# mean        1.679373
# std         0.897408
# min         0.200000
# 25%         1.002044
# 50%         1.524697
# 75%         2.193153
# max         5.687441
# Name: throughput, dtype: float64
# count    5880.000000
# mean        1.598344
# std         0.862115
# min         0.200000
# 25%         0.960428
# 50%         1.425693
# 75%         2.073970
# max         5.688606
# Name: throughput, dtype: float64
# count    5880.000000
# mean        1.544045
# std         0.832392
# min         0.200000
# 25%         0.928690
# 50%         1.363475
# 75%         1.983867
# max         5.919803
# Name: throughput, dtype: float64
# count    5880.000000
# mean        1.654456
# std         0.878083
# min         0.200000
# 25%         0.997548
# 50%         1.477009
# 75%         2.167381
# max         5.507541
# Name: throughput, dtype: float64
